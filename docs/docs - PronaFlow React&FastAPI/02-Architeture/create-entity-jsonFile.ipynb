# %%
import pandas as pd

# %%
files = pd.read_csv('./entityName.txt', header=None).squeeze().tolist()
files
# Out:
# ['AccessReview',
#  'AdminAuditLog',
#  'AdminPermission',
#  'AdminRole',
#  'AdminRolePermission',
#  'AdminUser',
#  'AdminUserRole',
#  'ApiScope',
#  'ApiToken',
#  'ApiTokenScope',
#  'ApiUsageLog',
#  'ApprovalAction',
#  'ApprovalRequest',
#  'ArchivedProject',
#  'ArchiveJob',
#  'ArchivePolicy',
#  'Article',
#  'ArticleFeedback',
#  'ArticleTag',
#  'ArticleTranslation',
#  'ArticleVersion',
#  'ArticleVisibility',
#  'AuditLog',
#  'AuthProvider',
#  'Backlink',
#  'BillingTransaction',
#  'Category',
#  'ChangeRequest',
#  'ChecklistItem',
#  'Client',
#  'Comment',
#  'ConsentGrant',
#  'DashboardLayouts',
#  'DataDiff',
#  'DataExportFile',
#  'DataExportRequest',
#  'DataTier',
#  'DeliveryAttempt',
#  'DeliveryChannel',
#  'DomainEvent',
#  'EventConsumer',
#  'Explanation',
#  'FailedSearch',
#  'FeatureBeacon',
#  'FeatureFlag',
#  'FeatureSnapshot',
#  'File',
#  'files.txt',
#  'FileVersion',
#  'FlowStep',
#  'FreelancerInvoice',
#  'InferenceRequest',
# ...

# %%
# Assuming you have an Entity class or similar that can be instantiated
# Adjust this based on your actual entity structure
for entity_name in files:
    # Example: load the entity data and export it
    # entity = Entity(entity_name)  # or load from somewhere
    # entity.export_json(f"./Entities/{entity_name}.json")
    
    # If you just need to create JSON files with the entity names:
    import json
    with open(f"./Entities/{entity_name}.json", 'w') as f:
        json.dump({"name": entity_name}, f)
